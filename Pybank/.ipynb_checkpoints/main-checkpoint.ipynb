# %%
from pathlib import Path
import csv
import pandas as pd

# %%
print(f"Current Working Directory: {Path.cwd()}")
# Out:
# Current Working Directory: C:\Users\norma\Desktop\Git_recent\python-homework\Pybank

# %%
csvpath = (r"C:\Users\norma\Desktop\Git_recent\python-homework\Pybank\budget_data.csv")

# %%
df = pd.read_csv(csvpath)
print(df)
print(df.loc[df['Profit/Losses'].argmax()])
print(df.loc[df['Profit/Losses'].idxmin()])
# Out:
#         Date  Profit/Losses
# 0   Jan-2010         867884
# 1   Feb-2010         984655
# 2   Mar-2010         322013
# 3   Apr-2010         -69417
# 4   May-2010         310503
# ..       ...            ...
# 81  Oct-2016         102685
# 82  Nov-2016         795914
# 83  Dec-2016          60988
# 84  Jan-2017         138230
# 85  Feb-2017         671099
#
# [86 rows x 2 columns]
# Date             Feb-2012
# Profit/Losses     1170593
# Name: 25, dtype: object
# Date             Sep-2013
# Profit/Losses    -1196225
# Name: 44, dtype: object

# %%
maxmonth = ("Feb-2012")
minmonth = ("Sep-2013")

# %%
with open(csvpath, 'r') as ccc:
    for line in csv.reader(ccc):
        print(line)
# Out:
# ['Date', 'Profit/Losses']
# ['Jan-2010', '867884']
# ['Feb-2010', '984655']
# ['Mar-2010', '322013']
# ['Apr-2010', '-69417']
# ['May-2010', '310503']
# ['Jun-2010', '522857']
# ['Jul-2010', '1033096']
# ['Aug-2010', '604885']
# ['Sep-2010', '-216386']
# ['Oct-2010', '477532']
# ['Nov-2010', '893810']
# ['Dec-2010', '-80353']
# ['Jan-2011', '779806']
# ['Feb-2011', '-335203']
# ['Mar-2011', '697845']
# ['Apr-2011', '793163']
# ['May-2011', '485070']
# ['Jun-2011', '584122']
# ['Jul-2011', '62729']
# ['Aug-2011', '668179']
# ['Sep-2011', '899906']
# ['Oct-2011', '834719']
# ['Nov-2011', '132003']
# ['Dec-2011', '309978']
# ['Jan-2012', '-755566']
# ['Feb-2012', '1170593']
# ['Mar-2012', '252788']
# ['Apr-2012', '1151518']
# ['May-2012', '817256']
# ['Jun-2012', '570757']
# ['Jul-2012', '506702']
# ['Aug-2012', '-1022534']
# ['Sep-2012', '475062']
# ['Oct-2012', '779976']
# ['Nov-2012', '144175']
# ['Dec-2012', '542494']
# ['Jan-2013', '359333']
# ['Feb-2013', '321469']
# ...

# %%
monthly_profit = []
line_num = 0

# %%
with open(csvpath, 'r') as csvfile:
    print(type(csvfile))
    csvreader = csv.reader(csvfile, delimiter=',')
    print(type(csvreader))
    header = next(csvreader)
    line_num += 1
    print(f"{header} <---- HEADER")
    for row in csvreader:
        print(row)
        profit = int(row[1])
        monthly_profit.append(profit)
        
months = 0
maxcash = 0
mincash = 0
totalavg = 0
totalcash = 0  

for profit in monthly_profit:
    totalcash += profit
    months += 1
    if mincash == 0:
        mincash = profit
    elif profit > maxcash:
        maxcash = profit
    elif profit < mincash:
        mincash = profit
        
totalavg = round(totalcash / months, 2)
print(maxcash, mincash, totalavg )
header = ["Highest Amount", "Lowest Amount", "Total Average"]
metrics = [maxcash, mincash, totalavg]
output_path = Path('financial_report.csv')
with open(output_path, 'w') as csvfile:
    csvwriter = csv.writer(csvfile, delimiter=',')
    csvwriter.writerow(header)
    csvwriter.writerow(metrics)
# Out:
# <class '_io.TextIOWrapper'>
# <class '_csv.reader'>
# ['Date', 'Profit/Losses'] <---- HEADER
# ['Jan-2010', '867884']
# ['Feb-2010', '984655']
# ['Mar-2010', '322013']
# ['Apr-2010', '-69417']
# ['May-2010', '310503']
# ['Jun-2010', '522857']
# ['Jul-2010', '1033096']
# ['Aug-2010', '604885']
# ['Sep-2010', '-216386']
# ['Oct-2010', '477532']
# ['Nov-2010', '893810']
# ['Dec-2010', '-80353']
# ['Jan-2011', '779806']
# ['Feb-2011', '-335203']
# ['Mar-2011', '697845']
# ['Apr-2011', '793163']
# ['May-2011', '485070']
# ['Jun-2011', '584122']
# ['Jul-2011', '62729']
# ['Aug-2011', '668179']
# ['Sep-2011', '899906']
# ['Oct-2011', '834719']
# ['Nov-2011', '132003']
# ['Dec-2011', '309978']
# ['Jan-2012', '-755566']
# ['Feb-2012', '1170593']
# ['Mar-2012', '252788']
# ['Apr-2012', '1151518']
# ['May-2012', '817256']
# ['Jun-2012', '570757']
# ['Jul-2012', '506702']
# ['Aug-2012', '-1022534']
# ['Sep-2012', '475062']
# ['Oct-2012', '779976']
# ['Nov-2012', '144175']
# ...

# %%
total_months = len(df.axes[0])
total_cash = df['Profit/Losses'].sum()
total_average = df['Profit/Losses'].mean()
increase = df['Profit/Losses'].max()
decrease = df['Profit/Losses'].min()

# %%
with open(csvpath, 'r') as csvfile:
    print("Financial Analysis")
    print("------------------------------")
    print(f"Total Months: {total_months}")
    print(f"Total: ${total_cash}")
    print(f"Average Change: ${total_average:.2f}")
    print(f"Greatest Increase in Profits: {maxmonth} (${increase})")
    print(f"Greatest Decrease in Profits: {minmonth} (${decrease})")
# Out:
# Financial Analysis
# ------------------------------
# Total Months: 86
# Total: $38382578
# Average Change: $446309.05
# Greatest Increase in Profits: Feb-2012 ($1170593)
# Greatest Decrease in Profits: Sep-2013 ($-1196225)

# %%
with open('budget_data.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile, delimiter = ',')
    for row in reader:
        print(row['Date'],row['Profit/Losses'])
# Out:
# Jan-2010 867884
# Feb-2010 984655
# Mar-2010 322013
# Apr-2010 -69417
# May-2010 310503
# Jun-2010 522857
# Jul-2010 1033096
# Aug-2010 604885
# Sep-2010 -216386
# Oct-2010 477532
# Nov-2010 893810
# Dec-2010 -80353
# Jan-2011 779806
# Feb-2011 -335203
# Mar-2011 697845
# Apr-2011 793163
# May-2011 485070
# Jun-2011 584122
# Jul-2011 62729
# Aug-2011 668179
# Sep-2011 899906
# Oct-2011 834719
# Nov-2011 132003
# Dec-2011 309978
# Jan-2012 -755566
# Feb-2012 1170593
# Mar-2012 252788
# Apr-2012 1151518
# May-2012 817256
# Jun-2012 570757
# Jul-2012 506702
# Aug-2012 -1022534
# Sep-2012 475062
# Oct-2012 779976
# Nov-2012 144175
# Dec-2012 542494
# Jan-2013 359333
# Feb-2013 321469
# Mar-2013 67780
# Apr-2013 471435
# May-2013 565603
# Jun-2013 872480
# Jul-2013 789480
# Aug-2013 999942
# Sep-2013 -1196225
# Oct-2013 268997
# Nov-2013 -687986
# Dec-2013 1150461
# Jan-2014 682458
# Feb-2014 617856
# Mar-2014 824098
# Apr-2014 581943
# May-2014 132864
# Jun-2014 448062
# Jul-2014 689161
# ...

# %%
totalavg = round(totalcash / months, 2)
print(maxcash, mincash, totalavg )
header = ["Highest Total", "Lowest Total", "Total Average"]
metrics = [maxcash, mincash, totalavg]
output_path = Path('financial_report.csv')
with open(output_path, 'w') as csvfile:
    csvwriter = csv.writer(csvfile, delimiter=',')
    csvwriter.writerow(header)
    csvwriter.writerow(metrics)
# Out:
# 1170593 -1196225
